# %%
import numpy as np
from scipy.stats import t

# %%
sample_mean=3050
theoritical_meean=1000+5*600
standard_deviation=5*25
sample_size=25
alpha=0.05

# %% [markdown]
# ### 1 QUESTION

# %% [markdown]
# State the Hypothesis Statement:

# %% [markdown]
# Null Hypothesis(Ho): The Weekly operating cost is consistent with the theoretical model(W = $1000+$5X).
# Alternative Hypothesis (H1): The Weekly operating cost is higher than the theoretical model.

# %% [markdown]
# ### 2ND QUESTION

# %%
standard_error=standard_deviation/np.sqrt(sample_size)
t_statistics=(sample_mean-theoritical_meean)/standard_error
print("Standard Error",standard_error)
print("T statistics",t_statistics)
# Out:
# Standard Error 25.0
# T statistics -38.0

# %% [markdown]
# ### 3RD QUESTION

# %%
hof=sample_size-1
critical_value=t.ppf(1-alpha,hof)
critical_value
# Out:
# 1.7108820799094275

# %% [markdown]
# ### 4TH QUESTON

# %%
if t_statistics<critical_value:
    print("Accept H0:The operating cost for a franchise in a week is not changed and remained same as $1000+$5X for X=600")
else:
    Print("Reject H0:The operating cost for a franchise in a week is changed as greater than $1000+$5X for X=600")
# Out:
# Accept H0:The operating cost for a franchise in a week is not changed and remained same as $1000+$5X for X=600

# %% [markdown]
# ### 5TH QUESTION

# %% [markdown]
# Based on the decision in step 4, conclude whether there is strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests.
