# %% [markdown]
# # 1 ST QUESTION

# %%
lst_nums = [10,17,19,24,36]
print(lst_nums)
# Out:
# [10, 17, 19, 24, 36]

# %%
lst_nums1 = []
lst_nums1.append(lst_nums)
print(lst_nums1)
# Out:
# [[10, 17, 19, 24, 36]]

# %%
lst_nums.extend([60,70,80,90,100])
print(lst_nums)
# Out:
# [10, 17, 19, 24, 36, 60, 70, 80, 90, 100]

# %%
lst_nums.insert(21,28)
print(lst_nums)
# Out:
# [10, 17, 19, 24, 36, 60, 70, 80, 90, 100, 28]

# %%
lst_nums.remove(24)
print(lst_nums)
# Out:
# [10, 17, 19, 36, 60, 70, 80, 90, 100, 28]

# %%
lst_nums.pop()
# Out:
# 28

# %%
lst_nums[3]
# Out:
# 36

# %%
lst_nums.count(70)
# Out:
# 1

# %%
lst_nums.sort()
print(lst_nums)
# Out:
# [10, 17, 19, 36, 60, 70, 80, 90, 100]

# %%
lst_nums.reverse()
print(lst_nums)
# Out:
# [100, 90, 80, 70, 60, 36, 19, 17, 10]

# %%
lst_nums.clear()
print(lst_nums)
# Out:
# []

# %% [markdown]
# # 2 ND QUESTION

# %%
tup = ("mani","gopi","kalyan")
tup
# Out:
# ('mani', 'gopi', 'kalyan')

# %%
tup[1]
# Out:
# 'gopi'

# %%
tup[1]=("Nani")
tup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tup[1]=("Nani")
#       2 tup
#
# TypeError: 'tuple' object does not support item assignment

# %% [raw]
#  EXPLANATION: In the tuple we cannot change the values.

# %% [markdown]
# # 3 RD QUESTION

# %%
S1 = (11,52,29,34,23,11,8,4,29,34)
print(S1)
set(S1)

# %% [raw]
# EXPLANATION: In sets the duplicate values dosennot exists it eleminates the duplicate values and arranges in Asscending order

# %% [markdown]
# # 4 TH QUESTION

# %%
D1 = {"name":"mani","age":23,"city":"ongole"}
print(D1)
# Out:
# {'name': 'mani', 'age': 23, 'city': 'ongole'}

# %%
D1["age"] = 24
print(D1)
# Out:
# {'name': 'mani', 'age': 24, 'city': 'ongole'}

# %%
D1["email"] = "123@gmail.com"
print(D1)
# Out:
# {'name': 'mani', 'age': 24, 'city': 'ongole', 'email': '123@gmail.com'}

# %%
D1
# Out:
# {'name': 'mani', 'age': 24, 'city': 'ongole', 'email': '123@gmail.com'}

# %% [markdown]
# # 5 TH QUESTION

# %%
age = int(input("enter the age:"))
if age  >= 18 :
    print("person is eligible for vote")
else:
    print("person is not eligible for vote")
# Out:
# enter the age: 22
# person is eligible for vote

# %% [markdown]
# # 6 TH QUESTION

# %%
marks = int(input("enter the marks:")) 
if marks >= 90:
    print('A')
elif marks >= 75 and marks < 90: 
    print('B')
elif marks >= 50 and marks < 75: 
    print('C')
else:
    print("Fail")
# Out:
# enter the marks: 73
# C

# %% [markdown]
# # 7 TH QUETION

# %%
a = int(input("enter the number:"))
if a > 0 :
    if a%2 ==0:
        print("positive and even number")
    else:
        print("positive and odd number")
elif a ==0:
    print("zero")
else:
    print("Negative")
# Out:
# enter the number: -4
# Negative

# %% [markdown]
# # 8 TH QUESTION

# %%
import numpy as np

# %%
a = np.array([10,20,40,60,90])
a
# Out:
# array([10, 20, 40, 60, 90])

# %%
num = ([1,2,3,4,5])

# %%
np.array(num)
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.array([[10,20,30],[40,50,60]])
b
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %% [markdown]
# # 9 TH QUESTION

# %%
C = np.random.randint(0,100,size=(4,4))
C
# Out:
# array([[67, 87, 80, 68],
#        [62, 20, 20,  8],
#        [77,  1,  3, 99],
#        [10, 45, 32, 83]])

# %% [markdown]
# # 10 TH QUESTION

# %%
E = np.array([[14,18,24],[21,26,19],[31,27,22]])
E
# Out:
# array([[14, 18, 24],
#        [21, 26, 19],
#        [31, 27, 22]])

# %%
import pandas as pd
df = pd.DataFrame(E)
df
# Out:
#     0   1   2
# 0  14  18  24
# 1  21  26  19
# 2  31  27  22

# %%
df.columns =['A','B','C']
df
# Out:
#     A   B   C
# 0  14  18  24
# 1  21  26  19
# 2  31  27  22
